# %%
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# Machine: Intel(R) Xeon(R) Gold 6148 CPU @ 2.40GHz (Intel18)
# Theoretical Peak = 96 Gflop/s

# %%
Ns = [1,10,25,50,80,100,150,200,300,400,600,1000,1200,1500,2000,3000,4000,5000]
Gflops = [float('inf'),0.15252,0.168041,0.169481,0.171237,0.172801,0.173503,0.173773,0.169164,0.148034,0.145389,0.141464,0.134565,0.13843,0.107956,0.0918691,0.0650135,0.07]

plt.figure(figsize=(5, 10))
plt.plot(Ns, Gflops, label='Measured Gflop/s')
plt.plot(Ns, [2.4] * len(Ns), label='Theoretical Gflop/s')
plt.title('Intel18 Gflop/s vs N')
plt.xlabel('N')
plt.ylabel('Gflop/s')
plt.legend()
plt.show()

# %% [markdown]
# AMD EPYC 7H12 64-Core Processor (AMD20)
# Theoretical Peak = 332.161152 Gflop/s

# %%
Ns = [1,10,25,50,80,100,150,200,300,400,600,1000,1200,1500,2000,3000,4000,5000]
Gflops = [float('inf'),0.164483,0.197994,0.20508,0.207166,0.207408,0.208514,0.208995,0.20955,0.198611,0.195936,0.186956,0.183494,0.178537,0.164265,0.129024,0.118527,0.123058]

plt.figure(figsize=(5, 10))
plt.plot(Ns, Gflops, label='Measured Gflop/s')
plt.plot(Ns, [2.60] * len(Ns), label='Theoretical Gflop/s')
plt.title('AMD20 Gflop/s vs N')
plt.xlabel('N')
plt.ylabel('Gflop/s')
plt.legend()
plt.show()
